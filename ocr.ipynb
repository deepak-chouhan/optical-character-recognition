# %%
import easyocr
import matplotlib.pyplot as plt
import cv2
from IPython.display import Image
from pylab import rcParams
from PIL import Image as img
rcParams['figure.figsize'] = 8, 16

# %%
reader = easyocr.Reader(['en'], gpu=False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
image_path = "./image.jpg"

# %%
Image(image_path)

# %%
import numpy as np
import pandas as pd

# %%
image = img.open(image_path)

# %%
output = reader.readtext(image)

# %%
output
# Out:
# [([[54, 32], [118, 32], [118, 56], [54, 56]], 'ThE', 0.5055399669554014),
#  ([[48, 48], [496, 48], [496, 144], [48, 144]],
#   'BUSINESS',
#   0.9998470883722957),
#  ([[312, 136], [486, 136], [486, 162], [312, 162]],
#   'MA G AZIN E',
#   0.6245082859940931),
#  ([[384, 274], [498, 274], [498, 298], [384, 298]],
#   'MAKE YOUR',
#   0.99780344687903),
#  ([[380, 294], [498, 294], [498, 322], [380, 322]],
#   'NEW IDEA',
#   0.9999227857387301),
#  ([[377, 331], [497, 331], [497, 343], [377, 343]],
#   'Lorem ipeum dolor sitamet;',
#   0.4821883107114562),
#  ([[390, 344], [490, 344], [490, 352], [390, 352]],
#   'cons auiciscing eiit se6',
#   0.08717713869807084),
#  ([[400, 360], [498, 360], [498, 384], [400, 384]],
#   'MEET THE',
#   0.9735748048686661),
#  ([[344, 380], [498, 380], [498, 406], [344, 406]],
#   'REAL LEADER',
#   0.9996896304910835),
#  ([[377, 419], [499, 419], [499, 431], [377, 431]],
#   'Lorem ipeum dolor sit amlet,',
#   0.18734978108972555),
#  ([[390, 430], [490, 430], [490, 438], [390, 438]],
#   'cons adiciscino elit_se0',
#   0.38785799055835635),
#  ([[414, 450], [500, 450], [500, 474], [414, 474]],
#   'STEP UP',
#   0.999486217387505),
#  ([[316, 468], [504, 468], [504, 496], [316, 496]],
#   'YOUR BUSINESS',
#   0.9997809072282271),
#  ([[355, 507], [497, 507], [497, 519], [355, 519]],
#   'Lorem ipsum dolor Gitamet cona',
#   0.4333315058294645),
#  ([[412, 518], [490, 518], [490, 526], [412, 526]],
#   'adlpiscing ellt_sed',
#   0.23874969010295208),
#  ([[34, 512], [260, 512], [260, 560], [34, 560]],
#   'YOUR WAY',
#   0.8034949402441208),
#  ([[34, 552], [304, 552], [304, 602], [34, 602]],
#   'TO SUCCESS',
#   0.8278579695777538),
#  ([[343, 577], [413, 577], [413, 595], [343, 595]],
#   'ISSUE 02',
#   0.8343239509262895),
#  ([[423, 577], [495, 577], [495, 595], [423, 595]],
#   'MAY 2028',
#   0.9556705079191276),
#  ([[37, 603], [289, 603], [289, 622], [37, 622]],
#   'Lorem ipsum dolor sit amet; consectetuer',
#   0.7253805650114543),
#  ([[37, 619], [249, 619], [249, 635], [37, 635]],
#   'adipiscing elit, sed diam nonummy',
#   0.9497145699636236),
#  ([[383, 651], [461, 651], [461, 665], [383, 665]],
#   '1234567890',
#   0.990813099181887)]

# %%
total_word = len(output)

# %%
image = cv2.imread("image.jpg")
for i in range(total_word):
    cord = output[i][0]
    x_min, y_min = [int(min(idx)) for idx in zip(*cord)]
    x_max, y_max = [int(max(idx)) for idx in zip(*cord)]
    cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 0, 255), 2)
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.savefig("result.png")
